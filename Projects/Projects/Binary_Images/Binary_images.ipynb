# %% [markdown]
# ## Blending

# %%
import cv2
import matplotlib.pyplot as plt

img_lena = cv2.imread("./Practice Images/lena.jpg")
img_lena = cv2.cvtColor(img_lena, cv2.COLOR_BGR2RGB)

img_j = cv2.imread("./Practice Images/j.png")
img_j = cv2.cvtColor(img_j, cv2.COLOR_BGR2RGB)

img_lena = cv2.resize(img_lena, (400,400))
img_j = cv2.resize(img_j, (400,400))

blended_image = cv2.addWeighted(img_lena, 0.7, img_j, 0.2, 0)

plt.imshow(img_lena)
plt.show()

plt.imshow(img_j)
plt.show()

plt.imshow(blended_image)
plt.show()

# %% [markdown]
# ## Binary Thresholding

# %%
img = cv2.imread("./Practice Images/rocket.jpg", 0)

ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

ret, thresh2 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

ret, thresh3 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)

ret, thresh4 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)

ret, thresh5 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO_INV)

titles = ['Original image', 'Binary', 'Binary Inv', 'Trunc', 'To Zero', 'To Zero Inv']

images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

plt.figure(figsize=(16,12))

for i in range(6):
    plt.subplot(2,3,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
